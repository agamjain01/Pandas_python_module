# %% [markdown]
# ##Read CSV Files

# %%
import pandas as pd
file =pd.read_csv("C:\\Users\\hp\\Downloads\\Python\\Read.csv")

file
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 24506    BDCQ.SEE3999A  2017.06         NaN          Y      F  Number
# 24507    BDCQ.SEE3999A  2017.09         NaN          Y      F  Number
# 24508    BDCQ.SEE3999A  2017.12         NaN          Y      F  Number
# 24509    BDCQ.SEE3999A  2018.03         NaN          Y      F  Number
# 24510    BDCQ.SEE3999A  2018.06         NaN          Y      F  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
file =pd.read_csv("C:\\Users\\hp\\Downloads\\Python\\Read.csv",usecols=["Subject" ,"Magnitude"])   # usecols use to find the particuler column 

file
# Out:
#        Magnitude                         Subject
# 0              0  Business Data Collection - BDC
# 1              0  Business Data Collection - BDC
# 2              0  Business Data Collection - BDC
# 3              0  Business Data Collection - BDC
# 4              0  Business Data Collection - BDC
# ...          ...                             ...
# 24506          0  Business Data Collection - BDC
# 24507          0  Business Data Collection - BDC
# 24508          0  Business Data Collection - BDC
# 24509          0  Business Data Collection - BDC
# 24510          0  Business Data Collection - BDC
#
# [24511 rows x 2 columns]

# %%
file =pd.read_csv("C:\\Users\\hp\\Downloads\\Python\\Read.csv",index_col="Subject")  # THAT IS  use for  change the column into index

file
# Out:
#                                Series_reference   Period  Data_value  \
# Subject
# Business Data Collection - BDC      BDCQ.SEA1AA  2011.06     80078.0
# Business Data Collection - BDC      BDCQ.SEA1AA  2011.09     78324.0
# Business Data Collection - BDC      BDCQ.SEA1AA  2011.12     85850.0
# Business Data Collection - BDC      BDCQ.SEA1AA  2012.03     90743.0
# Business Data Collection - BDC      BDCQ.SEA1AA  2012.06     81780.0
# ...                                         ...      ...         ...
# Business Data Collection - BDC    BDCQ.SEE3999A  2017.06         NaN
# Business Data Collection - BDC    BDCQ.SEE3999A  2017.09         NaN
# Business Data Collection - BDC    BDCQ.SEE3999A  2017.12         NaN
# Business Data Collection - BDC    BDCQ.SEE3999A  2018.03         NaN
# Business Data Collection - BDC    BDCQ.SEE3999A  2018.06         NaN
#
#                                Suppressed STATUS   UNITS  Magnitude  \
# Subject
# ...

# %%
# we are skip any row with the help of skiprows function 

file =pd.read_csv("C:\\Users\\hp\\Downloads\\Python\\Read.csv",skiprows=[2,5])

file
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.09     79261.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.12     87793.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 24504    BDCQ.SEE3999A  2017.06         NaN          Y      F  Number
# 24505    BDCQ.SEE3999A  2017.09         NaN          Y      F  Number
# 24506    BDCQ.SEE3999A  2017.12         NaN          Y      F  Number
# 24507    BDCQ.SEE3999A  2018.03         NaN          Y      F  Number
# 24508    BDCQ.SEE3999A  2018.06         NaN          Y      F  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
file =pd.read_csv("C:\\Users\\hp\\Downloads\\Python\\Read.csv" ,nrows=2) # that function help in show the limited row  

file
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06       80078         NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09       78324         NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# 0    Filled jobs  Agriculture, Forestry and Fishing         Actual
# 1    Filled jobs  Agriculture, Forestry and Fishing         Actual
#
#    Series_title_4  Series_title_5
# 0             NaN             NaN
# 1             NaN             NaN

# %%
# we are change the header of csv file then we are use header fun..
file =pd.read_csv("C:\\Users\\hp\\Downloads\\Python\\Read.csv" ,header=2)   

file
# Out:
#          BDCQ.SEA1AA  2011.09    78324 Unnamed: 3  F  Number  0  \
# 0        BDCQ.SEA1AA  2011.12  85850.0        NaN  F  Number  0
# 1        BDCQ.SEA1AA  2012.03  90743.0        NaN  F  Number  0
# 2        BDCQ.SEA1AA  2012.06  81780.0        NaN  F  Number  0
# 3        BDCQ.SEA1AA  2012.09  79261.0        NaN  F  Number  0
# 4        BDCQ.SEA1AA  2012.12  87793.0        NaN  F  Number  0
# ...              ...      ...      ...        ... ..     ... ..
# 24504  BDCQ.SEE3999A  2017.06      NaN          Y  F  Number  0
# 24505  BDCQ.SEE3999A  2017.09      NaN          Y  F  Number  0
# 24506  BDCQ.SEE3999A  2017.12      NaN          Y  F  Number  0
# 24507  BDCQ.SEE3999A  2018.03      NaN          Y  F  Number  0
# 24508  BDCQ.SEE3999A  2018.06      NaN          Y  F  Number  0
#
#        Business Data Collection - BDC  \
# 0      Business Data Collection - BDC
# 1      Business Data Collection - BDC
# 2      Business Data Collection - BDC
# 3      Business Data Collection - BDC
# ...

# %%
# we are change the header name  of csv file then we are use header  fun..
file =pd.read_csv("C:\\Users\\hp\\Downloads\\Python\\Read.csv" ,names =["inedx1"] )   

file
# Out:
#                                                                                                                                                                                                                                                                     inedx1
# Series_reference Period  Data_value Suppressed STATUS UNITS  Magnitude Subject                        Group                                        Series_title_1                         Series_title_2                     Series_title_3 Series_title_4  Series_title_5
# BDCQ.SEA1AA      2011.06 80078      NaN        F      Number 0         Business Data Collection - BDC Industry by employment variable              Filled jobs                            Agriculture, Forestry and Fishing  Actual         NaN                        NaN
# ...

# %%
 file =pd.read_csv("C:\\Users\\hp\\Downloads\\Python\\Read.csv" ,dtype={"Data_value":"float"},usecols=["Data_value"])   

file
# Out:
#        Data_value
# 0         80078.0
# 1         78324.0
# 2         85850.0
# 3         90743.0
# 4         81780.0
# ...           ...
# 24506         NaN
# 24507         NaN
# 24508         NaN
# 24509         NaN
# 24510         NaN
#
# [24511 rows x 1 columns]
